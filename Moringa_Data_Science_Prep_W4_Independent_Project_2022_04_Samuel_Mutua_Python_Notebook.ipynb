# %% [markdown]
# <a href="https://colab.research.google.com/github/Sammy-Mutua/IP-Week-4/blob/main/Moringa_Data_Science_Prep_W4_Independent_Project_2022_04_Samuel_Mutua_Python_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('Autolib.csv')

df.head(10)
# Out:
#                               Address  Cars  Bluecar counter  Utilib counter  \
# 0                 2 Avenue de Suffren     0                0               0
# 1           145 Rue Raymond Losserand     6                6               0
# 2    2 Avenue John Fitzgerald Kennedy     3                3               0
# 3              51 Rue EugÃ¨ne OudinÃ©     3                3               1
# 4  6 avenue de la Porte de Champerret     3                3               0
# 5                8 Boulevard Voltaire     0                0               0
# 6                      37 rue Leblanc     0                0               0
# 7         17 Rue des Luaps ProlongÃ©e     3                3               1
# 8               34 avenue Jean Moulin     1                1               0
# 9        41 boulevard de Rochechouart     6                6               0
#
#    Utilib 1.4 counter  Charge Slots Charging Status        City  \
# ...

# %%
df2 = df.filter(['Address','Cars','City','ID','Public name','Slots','year','month','day','hour'], axis=1)
df2
# Out:
#                                  Address  Cars                City  \
# 0                    2 Avenue de Suffren     0               Paris
# 1              145 Rue Raymond Losserand     6               Paris
# 2       2 Avenue John Fitzgerald Kennedy     3          Le Bourget
# 3                 51 Rue EugÃ¨ne OudinÃ©     3               Paris
# 4     6 avenue de la Porte de Champerret     3               Paris
# ...                                  ...   ...                 ...
# 4995                 8 avenue MÃ©nelotte     2            Colombes
# 4996                   37 rue de Dantzig     4               Paris
# 4997                      142 rue du Bac     1               Paris
# 4998         2 avenue du Val de Fontenay     2  Fontenay-Sous-Bois
# 4999                 5 Rue Henry Brisson     4               Paris
#
#                                      ID                           Public name  \
# 0                       paris-suffren-2                       Paris/Suffren/2
# ...

# %%
df3 = df2.loc[(df2['City'] == 'Paris') & (df2['year'] == 2018) & (df2['month'] == 4)]
df3
# Out:
#                                  Address  Cars   City  \
# 0                    2 Avenue de Suffren     0  Paris
# 1              145 Rue Raymond Losserand     6  Paris
# 3                 51 Rue EugÃ¨ne OudinÃ©     3  Paris
# 4     6 avenue de la Porte de Champerret     3  Paris
# 5                   8 Boulevard Voltaire     0  Paris
# ...                                  ...   ...    ...
# 4992                     3 avenue d'Ivry     0  Paris
# 4994                    15 rue de Rocroy     0  Paris
# 4996                   37 rue de Dantzig     4  Paris
# 4997                      142 rue du Bac     1  Paris
# 4999                 5 Rue Henry Brisson     4  Paris
#
#                               ID                  Public name  Slots  year  \
# 0                paris-suffren-2              Paris/Suffren/2      2  2018
# 1     paris-raymondlosserand-145  Paris/Raymond Losserand/145      0  2018
# 3          paris-eugeneoudine-51     Paris/EugÃ¨ne OudinÃ©/51      2  2018
# ...

# %%
df4 = df3.sort_values("Cars")
df4
# Out:
#                          Address  Cars   City                  ID  \
# 0            2 Avenue de Suffren     0  Paris     paris-suffren-2
# 2689           3 Rue Yves Toudic     0  Paris  paris-yvestoudic-3
# 2685    16 place des Ãtats-Unis     0  Paris  paris-etatsunis-16
# 2680         11 Avenue Richerand     0  Paris  paris-richerand-11
# 2678         249 avenue Gambetta     0  Paris  paris-gambetta-249
# ...                          ...   ...    ...                 ...
# 2528            150 rue Marcadet     6  Paris  paris-marcadet-150
# 646            1 rue Jean Sicard     6  Paris  paris-jeansicard-1
# 1024              2 rue des Eaux     6  Paris        paris-eaux-2
# 2470  2 rue du GÃ©nÃ©ral Renault     7  Paris     paris-renault-2
# 3115  2 rue du GÃ©nÃ©ral Renault     7  Paris     paris-renault-2
#
#                Public name  Slots  year  month  day  hour
# 0          Paris/Suffren/2      2  2018      4    8    11
# ...

# %%
df4.hour.mode()
# Out:
# 0    21
# dtype: int64
